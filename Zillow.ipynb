# %%
import pandas as pd
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import KNNImputer
from sklearn.preprocessing import MinMaxScaler, StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
import xgboost as xgb
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, mean_absolute_percentage_error
import matplotlib.pyplot as plt
import joblib
import prince
from mlens.ensemble import SuperLearner
from sklearn.base import BaseEstimator, TransformerMixin
# Out:
# [MLENS] backend: threading

# %%
dat = pd.read_csv('training_ZILLOW_CONFIDENTIAL.csv')
dat_test = pd.read_csv('test_ZILLOW_CONFIDENTIAL.csv')
dat_train = dat.drop('SaleDollarCnt', axis = 1)
dat_test = dat_test.drop('SaleDollarCnt', axis = 1)
target = dat['SaleDollarCnt']

# %%
dat.loc[dat.GarageSquareFeet.isna(), 'PropertyID']
# Out:
# 3         48649040
# 4         48649057
# 6         48649122
# 7         48649137
# 8         48649324
#            ...
# 11417    122181248
# 11432    122182157
# 11479    122962619
# 11564    124003199
# 11580    124393049
# Name: PropertyID, Length: 2841, dtype: int64

# %%
dat_train.shape, dat_test.shape
# Out:
# ((11588, 23), (4402, 23))

# %%
np.sum(pd.isna(dat_train))
# Out:
# PropertyID               0
# TransDate                0
# censusblockgroup         0
# ZoneCodeCounty           0
# Usecode                  0
# BedroomCnt               0
# BathroomCnt              0
# FinishedSquareFeet       0
# GarageSquareFeet      2841
# LotSizeSquareFeet        0
# StoryCnt                 0
# BuiltYear                0
# ViewType              8956
# Latitude                 0
# Longitude                0
# BGMedHomeValue           6
# BGMedRent             2631
# BGMedYearBuilt         247
# BGPctOwn                 0
# BGPctVacant              0
# BGMedIncome              0
# BGPctKids                0
# BGMedAge                 0
# dtype: int64

# %% [markdown]
# ## Preprocessing (option 1): Using onehotencoding to encoding categorical data
#
# - PropertyID: remove;
# - Usecode: remove;
# - TransDate: convert it to be the num of days from one date to '01/01/2015', then divide it by 366;
# - ViewType: Treat 'NA' as another category
# - censusblockgroup: drive the FIPS code by truncating the rightmost digit
# - BGMedIncome: make a log transformation
# - BGMedHomeValue: make a log transformation
#
# Apply one-hot encoding to deal with categorical varialbes

# %%
## Preprocessing
# PropertyID: remove
# Usecode: remove
# TransDate: convert transdate to be the difference in days from one date to '01/01/2015'
# ViewType: fill na with 0 and then covert to be categorical.
dat_all = pd.concat([dat_train, dat_test])
dat_all = dat_all.drop(['PropertyID','Usecode'], axis = 1)
dat_all['TransDate'] = (pd.to_datetime(dat_all['TransDate']) - pd.to_datetime('01/01/2015')).dt.days/366
dat_all['ViewType'] = (dat_all['ViewType'].fillna(0)).astype(object)
dat_all['censusblockgroup'] = dat_all['censusblockgroup'].map(lambda x: str(x)[:-1])
dat_all['BGMedIncome'] = np.log(dat_all['BGMedIncome'])
dat_all['BGMedHomeValue'] = np.log(dat_all['BGMedHomeValue'])

con_var = ['FinishedSquareFeet','GarageSquareFeet', 'LotSizeSquareFeet',
           'BGMedHomeValue', 'BGMedRent', 'BGMedYearBuilt','BGMedIncome', 
           'BGMedAge', 'BuiltYear', 'BGPctOwn', 'BGPctVacant', 'BGPctKids', 
           'TransDate','BedroomCnt', 'BathroomCnt', 'StoryCnt','Latitude', 
           'Longitude']

cat_var = ['censusblockgroup','ZoneCodeCounty', 'ViewType']

dat_train_after = dat_all.iloc[:dat_train.shape[0],]
dat_test_after = dat_all.iloc[dat_train.shape[0]:, ]

X_train, X_test, y_train, y_test = train_test_split(dat_train_after, target, train_size=0.8)


class IdentityTransformer(BaseEstimator, TransformerMixin):
    def __init__(self):
        pass
    
    def fit(self, input_array, y=None):
        return self
    
    def transform(self, input_array, y=None):
        return input_array*1

class KNNimputer_dat(BaseEstimator, TransformerMixin):
    def __init__(self, n_neighbors=5):
        self.n_neighbors = n_neighbors
        self.KNNimputer = KNNImputer(n_neighbors = n_neighbors)
    
    def fit(self, X, y=None):
        self.KNNimputer.fit(X)
        return self
    
    def transform(self, X, y=None):
        col_names = X.columns
        index = X.index
        X_imputed = self.KNNimputer.transform(X)
        X_imputed = pd.DataFrame(X_imputed, columns=col_names, index = index)
        return X_imputed


num_ColumnTrans = ColumnTransformer([
    ('std_scale', StandardScaler(), ['FinishedSquareFeet','GarageSquareFeet', 'LotSizeSquareFeet',
                                     'BGMedHomeValue', 'BGMedRent', 'BGMedYearBuilt','BGMedIncome', 
                                     'BGMedAge', 'BuiltYear']),
    ('Identity', IdentityTransformer(), ['BGPctOwn', 'BGPctVacant', 'BGPctKids', 'TransDate']),
    ('Minmax_scale', MinMaxScaler(), ['BedroomCnt', 'BathroomCnt', 
                                      'StoryCnt','Latitude', 
                                      'Longitude'])
])


num_transformer = Pipeline(steps=[
    ('KNNimputer', KNNimputer_dat(n_neighbors=5)),
    ('scaler', num_ColumnTrans)
])

mypreprocessor = ColumnTransformer([
    ('num', num_transformer, con_var),
    ('Ohot2blockgroup', OneHotEncoder(handle_unknown='ignore'), ['censusblockgroup']),
    ('Ohot2ZoneCode', OneHotEncoder(handle_unknown='ignore'), ['ZoneCodeCounty']),
    ('Ohot2ViewType', OneHotEncoder(handle_unknown='ignore'), ['ViewType'])
])

# %% [markdown]
# ## Preprocessing (option 2): Using MAC to encoding categorical data
#
# - PropertyID: remove;
# - Usecode: remove;
# - TransDate: convert it to be the num of days from one date to '01/01/2015', then divide it by 366;
# - ViewType: Treat 'NA' as another category
# - censusblockgroup: drive the FIPS code by truncating the rightmost digit
# - BGMedIncome: make a log transformation
# - BGMedHomeValue: make a log transformation
#
# Apply MCA deal with variables 'censusblockgroup' and 'ZoneCodeCounty' because of their numbers of categories are large.
# Apply one-hot encoder on 'ViewType'.

# %%
## Preprocessing
# PropertyID: remove
# Usecode: remove
# TransDate: convert transdate to be the difference in days from one date to '01/01/2015'
# ViewType: fill na with 0 and then covert to be categorical.
dat_all = pd.concat([dat_train, dat_test])
dat_all = dat_all.drop(['PropertyID','Usecode'], axis = 1)
dat_all['TransDate'] = (pd.to_datetime(dat_all['TransDate']) - pd.to_datetime('01/01/2015')).dt.days/366 
dat_all['ViewType'] = (dat_all['ViewType'].fillna(0)).astype(object)
dat_all['censusblockgroup'] = dat_all['censusblockgroup'].map(lambda x: str(x)[:-1])


con_var = ['BedroomCnt', 'BathroomCnt', 'StoryCnt', 'FinishedSquareFeet', 
           'GarageSquareFeet', 'LotSizeSquareFeet' , 'Latitude', 'Longitude',
           'BGMedHomeValue', 'BGMedRent', 'BGMedYearBuilt', 
           'BGPctOwn', 'BGPctVacant','BGMedIncome', 'BGPctKids', 'BGMedAge', 
           'BuiltYear','TransDate']
cat_var = ['censusblockgroup','ZoneCodeCounty', 'ViewType']

n_component =5
mac = prince.MCA(n_components=n_component)
num_reprsent = mac.fit_transform(dat_all[['censusblockgroup','ZoneCodeCounty']])
MCA_columns = [f'rep_{i}' for i in range(n_component)]
num_reprsent.columns = MCA_columns
dat_all = pd.concat([dat_all[con_var], dat_all['ViewType'], num_reprsent], axis=1)


dat_train_after = dat_all.iloc[:dat_train.shape[0],]
dat_test_after = dat_all.iloc[dat_train.shape[0]:, ]


# ## deal 'censusblockgroup'
# min_num = 5
# category_blockgroup = []
# for cat in dat_train_after['censusblockgroup'].unique():
#     if len(dat_train_after[dat_train_after['censusblockgroup'] == cat]) >= min_num:
#         category_blockgroup.append(cat)
# dat_train_after['censusblockgroup'] = dat_train_after['censusblockgroup'].map(lambda x: x if x in category_blockgroup else 'other')
# dat_test_after['censusblockgroup'] = dat_test_after['censusblockgroup'].map(lambda x: x if x in category_blockgroup else 'other')        

# ## deal 'ZoneCodeCounty'
# min_num = 5
# category_ZoneCode= []
# for cat in dat_train_after['ZoneCodeCounty'].unique():
#     if len(dat_train_after[dat_train_after['ZoneCodeCounty'] == cat]) >= min_num:
#         category_ZoneCode.append(cat)
# dat_train_after['ZoneCodeCounty'] = dat_train_after['ZoneCodeCounty'].map(lambda x: x if x in category_ZoneCode else 'other')
# dat_test_after['ZoneCodeCounty'] = dat_test_after['ZoneCodeCounty'].map(lambda x: x if x in category_ZoneCode else 'other')        



X_train, X_test, y_train, y_test = train_test_split(dat_train_after, target, train_size=0.85)

class IdentityTransformer(BaseEstimator, TransformerMixin):
    def __init__(self):
        pass
    
    def fit(self, input_array, y=None):
        return self
    
    def transform(self, input_array, y=None):
        return input_array*1

class KNNimputer_dat(BaseEstimator, TransformerMixin):
    def __init__(self, n_neighbors=5):
        self.n_neighbors = n_neighbors
        self.KNNimputer = KNNImputer(n_neighbors = n_neighbors)
    
    def fit(self, X, y=None):
        self.KNNimputer.fit(X)
        return self
    
    def transform(self, X, y=None):
        col_names = X.columns
        index = X.index
        X_imputed = self.KNNimputer.transform(X)
        X_imputed = pd.DataFrame(X_imputed, columns=col_names, index = index)
        return X_imputed


num_ColumnTrans = ColumnTransformer([
    ('std_scale', StandardScaler(), ['FinishedSquareFeet','GarageSquareFeet', 'LotSizeSquareFeet',
                                     'BGMedHomeValue', 'BGMedRent', 'BGMedYearBuilt','BGMedIncome', 
                                     'BGMedAge', 'BuiltYear']),
    ('Identity', IdentityTransformer(), ['BGPctOwn', 'BGPctVacant', 'BGPctKids', 'TransDate']),
    ('Minmax_scale', MinMaxScaler(), ['BedroomCnt', 'BathroomCnt', 
                                      'StoryCnt','Latitude', 
                                      'Longitude'])
])


num_transformer = Pipeline(steps=[
    ('KNNimputer', KNNimputer_dat(n_neighbors=5)),
    ('scaler', num_ColumnTrans)
])



# class category_MAC(BaseEstimator, TransformerMixin):
#     def __init__(self, n_compent, min_num = 5):
#         self.mac = prince.MCA(n_components=n_component)
#         self.category_blockgroup = []
#         self.category_ZoneCode= []
#         self.min_num = 5
    
#     def fit(self, X, y=None):
#         for cat in X['censusblockgroup'].unique():
#             if len(X[X['censusblockgroup'] == cat]) >= self.min_num:
#                 self.category_blockgroup.append(cat)
#         X['censusblockgroup'] = X['censusblockgroup'].map(lambda x: x if x in self.category_blockgroup else 'other')
#         for cat in X['ZoneCodeCounty'].unique():
#             if len(X[X['ZoneCodeCounty'] == cat]) >= self.min_num:
#                 self.category_ZoneCode.append(cat)
#         X['ZoneCodeCounty'] = X['ZoneCodeCounty'].map(lambda x: x if x in self.category_ZoneCode else 'other')
#         self.mac.fit(X)
#         return self
    
#     def transform(self, X, y =None):
#         X['censusblockgroup'] = X['censusblockgroup'].map(lambda x: x if x in self.category_blockgroup else 'other')
#         X['ZoneCodeCounty'] = X['ZoneCodeCounty'].map(lambda x: x if x in self.category_ZoneCode else 'other')
#         return self.mac.transform(X)


mypreprocessor = ColumnTransformer([
    ('num', num_transformer, con_var),
    ('Identidy', IdentityTransformer(), MCA_columns),
    ('Onehotencoder', OneHotEncoder(), ['ViewType'])
])

# %% [markdown]
# ## Define a custom metric function
#
# I customize a metric funcition, because I treat log('SaleDollarCnt') as the reponse in the model.

# %%
## define a metric function 
def myloss(y_true, y_pred):
    return np.mean(abs(np.exp(y_true) - np.exp(y_pred)) / np.exp(y_true))

myscore = make_scorer(myloss, greater_is_better=False)

# %% [markdown]
# # Modeling
# ## XGBRegressor

# %%
## fix a large learning rate 0.1, 
## then find a n_estimator for future parameter tuning

X_train_processed = mypreprocessor.fit_transform(X_train)
X_test_processed = mypreprocessor.transform(X_test)
bestXGB = XGBRegressor(colsample_bytree=0.8,
                       learning_rate=0.1,
                       reg_lambda = 0.1,
                       reg_alpha = 0.1,
                       max_depth=5,
                       min_child_weight=1,
                       n_estimators=50000,                                                                    
                       eval_metric = myloss,
                       early_stopping_rounds = 10,
                       subsample=0.6, seed = 42)
bestXGB.fit(X_train_processed, np.log(y_train), eval_set = [(X_test_processed, np.log(y_test))])

# %%
## Step1 Tune max_depth and min_child_weight with n_estimators = 250
param_grid1 = {'model__max_depth': [3,5,6,8,10],
               'model__min_child_weight': [1,2,4,6,8,10],               
}

pipe1 = Pipeline([
    ('preprocessor', mypreprocessor),
    ('model', XGBRegressor(colsample_bytree=0.8,
                           learning_rate=0.1,
                           reg_lambda = 0.1,
                           reg_alpha = 0.1,
                           max_depth=5,
                           min_child_weight=1,
                           n_estimators=250,                                                                    
                           eval_metric = myloss,
                           subsample=0.5, seed = 42))
])

grid_search1 = GridSearchCV(pipe1, param_grid1, scoring=myscore, n_jobs=-1)
target_log = np.log(target)
grid_search1.fit(dat_train_after, target_log)

# %%
grid_search1.best_score_, grid_search1.best_params_
# Out:
# (-0.12787269280796282, {'model__max_depth': 6, 'model__min_child_weight': 2})

# %%
## Step 2: Tune gamma

pipe = Pipeline([
    ('preprocessor', mypreprocessor),
    ('model', XGBRegressor(colsample_bytree=0.8,
                           learning_rate=0.1,
                           reg_lambda = 0.1,
                           reg_alpha = 0.1,
                           max_depth=6,
                           min_child_weight=2,
                           n_estimators=250,                                                                    
                           eval_metric = myloss,
                           subsample=0.5, seed = 42))
])

param_grid2 = {
 'model__gamma':[i/10.0 for i in range(0,11)]
}

grid_search2 = GridSearchCV(pipe, param_grid2, scoring=myscore, n_jobs=-1)
target_log = np.log(target)
grid_search2.fit(dat_train_after, target_log)

# %%
grid_search2.best_score_, grid_search2.best_params_,
# Out:
# (-0.12787269280796282, {'model__gamma': 0.0})

# %%
# Step 3: Tune subsample and colsample_bytree
pipe3 = Pipeline([
    ('preprocessor', mypreprocessor),
    ('model', XGBRegressor(learning_rate=0.1,
                           reg_lambda = 0.1,
                           reg_alpha = 0.1,
                           gamma = 0,
                           max_depth=6,
                           min_child_weight=2,
                           n_estimators=250,                                                                    
                           eval_metric = myloss,
                           subsample=0.5,
                           colsample_bytree=0.8,
                           seed = 42))
])

param_grid3 = {
 'model__subsample':[i/10.0 for i in range(3,11)],
 'model__colsample_bytree':[i/10.0 for i in range(5,11)]
}

grid_search3 = GridSearchCV(pipe3, param_grid3, scoring=myscore, n_jobs=-1)
target_log = np.log(target)
grid_search3.fit(dat_train_after, target_log)

# %%
grid_search3.best_params_, grid_search3.best_score_
# Out:
# ({'model__colsample_bytree': 0.6, 'model__subsample': 0.9},
#  -0.12634547312715258)

# %%
## Step 4: Tuning Regularization Parameters

pipe4 = Pipeline([
    ('preprocessor', mypreprocessor),
    ('model', XGBRegressor(learning_rate=0.1,
                           reg_lambda = 0.1,
                           reg_alpha = 0.1,
                           gamma = 0,
                           max_depth=6,
                           min_child_weight=2,
                           n_estimators=250,                                                                    
                           eval_metric = myloss,
                           subsample=0.9,
                           colsample_bytree=0.6,
                           seed = 42))
])

param_grid4 = {
 'model__reg_lambda':[0, 1e-3, 1e-2, 0.1, 1,10, 100],
 'model__reg_alpha':[0, 1e-3, 1e-2, 0.1, 1, 10, 100]
}

grid_search4 = GridSearchCV(pipe4, param_grid4, scoring=myscore, n_jobs=-1)
target_log = np.log(target)
grid_search4.fit(dat_train_after, target_log)

# %%
grid_search4.best_params_, grid_search4.best_score_
# Out:
# ({'model__reg_alpha': 1, 'model__reg_lambda': 0.01}, -0.12499748148609904)

# %%
## Step 5: Reducing Learning Rate and refit the model
X_train_processed = mypreprocessor.fit_transform(X_train)
X_test_processed = mypreprocessor.transform(X_test)
bestXGB = XGBRegressor(colsample_bytree=0.6,
                       gamma = 0,
                       learning_rate=0.01,
                       reg_lambda = 0.01,
                       reg_alpha = 1,
                       max_depth=6,
                       min_child_weight=2,
                       n_estimators=30000,                                                                    
                       eval_metric = myloss,
                       early_stopping_rounds = 50,
                       subsample=0.9, seed = 42)
bestXGB.fit(X_train_processed, np.log(y_train), eval_set = [(X_test_processed, np.log(y_test))])
# Out:
# [0]	validation_0-rmse:12.57090	validation_0-myloss:1.00000
# [1]	validation_0-rmse:12.44534	validation_0-myloss:1.00000
# [2]	validation_0-rmse:12.32100	validation_0-myloss:0.99999
# [3]	validation_0-rmse:12.19791	validation_0-myloss:0.99999
# [4]	validation_0-rmse:12.07607	validation_0-myloss:0.99999
# [5]	validation_0-rmse:11.95537	validation_0-myloss:0.99999
# [6]	validation_0-rmse:11.83592	validation_0-myloss:0.99999
# [7]	validation_0-rmse:11.71771	validation_0-myloss:0.99999
# [8]	validation_0-rmse:11.60068	validation_0-myloss:0.99999
# [610]	validation_0-rmse:0.18235	validation_0-myloss:0.12589
# [611]	validation_0-rmse:0.18229	validation_0-myloss:0.12587
# [612]	validation_0-rmse:0.18222	validation_0-myloss:0.12586
# [613]	validation_0-rmse:0.18215	validation_0-myloss:0.12584
# [614]	validation_0-rmse:0.18210	validation_0-myloss:0.12582
# [615]	validation_0-rmse:0.18203	validation_0-myloss:0.12580
# [616]	validation_0-rmse:0.18196	validation_0-myloss:0.12577
# [617]	validation_0-rmse:0.18189	validation_0-myloss:0.12574
# [618]	validation_0-rmse:0.18182	validation_0-myloss:0.12572
# [619]	validation_0-rmse:0.18176	validation_0-myloss:0.12571
# [620]	validation_0-rmse:0.18171	validation_0-myloss:0.12568
# [621]	validation_0-rmse:0.18164	validation_0-myloss:0.12566
# [622]	validation_0-rmse:0.18156	validation_0-myloss:0.12563
# [623]	validation_0-rmse:0.18144	validation_0-myloss:0.12558
# [624]	validation_0-rmse:0.18137	validation_0-myloss:0.12555
# [625]	validation_0-rmse:0.18132	validation_0-myloss:0.12554
# [626]	validation_0-rmse:0.18123	validation_0-myloss:0.12551
# [627]	validation_0-rmse:0.18114	validation_0-myloss:0.12548
# [628]	validation_0-rmse:0.18106	validation_0-myloss:0.12543
# [629]	validation_0-rmse:0.18100	validation_0-myloss:0.12542
# [630]	validation_0-rmse:0.18092	validation_0-myloss:0.12538
# [631]	validation_0-rmse:0.18087	validation_0-myloss:0.12537
# [632]	validation_0-rmse:0.18082	validation_0-myloss:0.12535
# [633]	validation_0-rmse:0.18075	validation_0-myloss:0.12533
# [634]	validation_0-rmse:0.18069	validation_0-myloss:0.12532
# [635]	validation_0-rmse:0.18063	validation_0-myloss:0.12530
# [636]	validation_0-rmse:0.18058	validation_0-myloss:0.12529
# [637]	validation_0-rmse:0.18052	validation_0-myloss:0.12529
# [638]	validation_0-rmse:0.18048	validation_0-myloss:0.12526
# [639]	validation_0-rmse:0.18038	validation_0-myloss:0.12521
# [640]	validation_0-rmse:0.18033	validation_0-myloss:0.12520
# [641]	validation_0-rmse:0.18027	validation_0-myloss:0.12516
# [642]	validation_0-rmse:0.18022	validation_0-myloss:0.12515
# [643]	validation_0-rmse:0.18012	validation_0-myloss:0.12511
# [644]	validation_0-rmse:0.18008	validation_0-myloss:0.12511
# [645]	validation_0-rmse:0.18001	validation_0-myloss:0.12508
# [646]	validation_0-rmse:0.17996	validation_0-myloss:0.12507
# [647]	validation_0-rmse:0.17990	validation_0-myloss:0.12505
# [648]	validation_0-rmse:0.17985	validation_0-myloss:0.12504
# [649]	validation_0-rmse:0.17979	validation_0-myloss:0.12503
# [650]	validation_0-rmse:0.17974	validation_0-myloss:0.12501
# [651]	validation_0-rmse:0.17969	validation_0-myloss:0.12499
# [652]	validation_0-rmse:0.17963	validation_0-myloss:0.12497
# [653]	validation_0-rmse:0.17960	validation_0-myloss:0.12496
# [654]	validation_0-rmse:0.17955	validation_0-myloss:0.12495
# [655]	validation_0-rmse:0.17950	validation_0-myloss:0.12494
# [703]	validation_0-rmse:0.17761	validation_0-myloss:0.12426
# [704]	validation_0-rmse:0.17757	validation_0-myloss:0.12426
# [705]	validation_0-rmse:0.17752	validation_0-myloss:0.12423
# [706]	validation_0-rmse:0.17747	validation_0-myloss:0.12421
# [707]	validation_0-rmse:0.17746	validation_0-myloss:0.12422
# [708]	validation_0-rmse:0.17743	validation_0-myloss:0.12421
# [709]	validation_0-rmse:0.17739	validation_0-myloss:0.12420
# [710]	validation_0-rmse:0.17737	validation_0-myloss:0.12419
# [711]	validation_0-rmse:0.17734	validation_0-myloss:0.12418
# [712]	validation_0-rmse:0.17731	validation_0-myloss:0.12416
# [713]	validation_0-rmse:0.17727	validation_0-myloss:0.12414
# [714]	validation_0-rmse:0.17724	validation_0-myloss:0.12413
# [715]	validation_0-rmse:0.17722	validation_0-myloss:0.12413
# [716]	validation_0-rmse:0.17720	validation_0-myloss:0.12412
# [717]	validation_0-rmse:0.17718	validation_0-myloss:0.12412
# [718]	validation_0-rmse:0.17716	validation_0-myloss:0.12412
# [719]	validation_0-rmse:0.17714	validation_0-myloss:0.12412
# [720]	validation_0-rmse:0.17709	validation_0-myloss:0.12409
# [721]	validation_0-rmse:0.17706	validation_0-myloss:0.12408
# [722]	validation_0-rmse:0.17703	validation_0-myloss:0.12407
# [723]	validation_0-rmse:0.17700	validation_0-myloss:0.12406
# [724]	validation_0-rmse:0.17697	validation_0-myloss:0.12405
# [725]	validation_0-rmse:0.17696	validation_0-myloss:0.12405
# [726]	validation_0-rmse:0.17694	validation_0-myloss:0.12406
# [727]	validation_0-rmse:0.17693	validation_0-myloss:0.12405
# [728]	validation_0-rmse:0.17690	validation_0-myloss:0.12405
# [729]	validation_0-rmse:0.17687	validation_0-myloss:0.12403
# [730]	validation_0-rmse:0.17683	validation_0-myloss:0.12401
# [731]	validation_0-rmse:0.17679	validation_0-myloss:0.12399
# [732]	validation_0-rmse:0.17674	validation_0-myloss:0.12396
# [733]	validation_0-rmse:0.17671	validation_0-myloss:0.12395
# [734]	validation_0-rmse:0.17668	validation_0-myloss:0.12395
# [735]	validation_0-rmse:0.17664	validation_0-myloss:0.12394
# [736]	validation_0-rmse:0.17661	validation_0-myloss:0.12392
# [737]	validation_0-rmse:0.17658	validation_0-myloss:0.12391
# [738]	validation_0-rmse:0.17654	validation_0-myloss:0.12387
# [739]	validation_0-rmse:0.17652	validation_0-myloss:0.12388
# [740]	validation_0-rmse:0.17649	validation_0-myloss:0.12386
# [741]	validation_0-rmse:0.17647	validation_0-myloss:0.12386
# [742]	validation_0-rmse:0.17645	validation_0-myloss:0.12386
# [743]	validation_0-rmse:0.17643	validation_0-myloss:0.12385
# [744]	validation_0-rmse:0.17640	validation_0-myloss:0.12383
# [745]	validation_0-rmse:0.17637	validation_0-myloss:0.12382
# [746]	validation_0-rmse:0.17634	validation_0-myloss:0.12381
# [747]	validation_0-rmse:0.17630	validation_0-myloss:0.12379
# [748]	validation_0-rmse:0.17628	validation_0-myloss:0.12379
# [749]	validation_0-rmse:0.17625	validation_0-myloss:0.12378
# [750]	validation_0-rmse:0.17622	validation_0-myloss:0.12376
# [751]	validation_0-rmse:0.17619	validation_0-myloss:0.12375
# [752]	validation_0-rmse:0.17617	validation_0-myloss:0.12373
# [753]	validation_0-rmse:0.17614	validation_0-myloss:0.12372
# [754]	validation_0-rmse:0.17612	validation_0-myloss:0.12372
# [755]	validation_0-rmse:0.17609	validation_0-myloss:0.12370
# [756]	validation_0-rmse:0.17604	validation_0-myloss:0.12367
# [757]	validation_0-rmse:0.17599	validation_0-myloss:0.12364
# [758]	validation_0-rmse:0.17595	validation_0-myloss:0.12361
# [759]	validation_0-rmse:0.17591	validation_0-myloss:0.12361
# [760]	validation_0-rmse:0.17589	validation_0-myloss:0.12360
# [761]	validation_0-rmse:0.17585	validation_0-myloss:0.12357
# [762]	validation_0-rmse:0.17583	validation_0-myloss:0.12356
# [763]	validation_0-rmse:0.17580	validation_0-myloss:0.12355
# [764]	validation_0-rmse:0.17576	validation_0-myloss:0.12352
# [765]	validation_0-rmse:0.17574	validation_0-myloss:0.12351
# [766]	validation_0-rmse:0.17568	validation_0-myloss:0.12347
# [767]	validation_0-rmse:0.17565	validation_0-myloss:0.12346
# [768]	validation_0-rmse:0.17562	validation_0-myloss:0.12345
# [769]	validation_0-rmse:0.17560	validation_0-myloss:0.12342
# [770]	validation_0-rmse:0.17559	validation_0-myloss:0.12342
# [771]	validation_0-rmse:0.17556	validation_0-myloss:0.12341
# [772]	validation_0-rmse:0.17554	validation_0-myloss:0.12341
# [773]	validation_0-rmse:0.17551	validation_0-myloss:0.12340
# [774]	validation_0-rmse:0.17550	validation_0-myloss:0.12340
# [775]	validation_0-rmse:0.17548	validation_0-myloss:0.12339
# [776]	validation_0-rmse:0.17546	validation_0-myloss:0.12338
# [777]	validation_0-rmse:0.17545	validation_0-myloss:0.12338
# [778]	validation_0-rmse:0.17543	validation_0-myloss:0.12337
# [779]	validation_0-rmse:0.17541	validation_0-myloss:0.12336
# [780]	validation_0-rmse:0.17540	validation_0-myloss:0.12335
# [781]	validation_0-rmse:0.17537	validation_0-myloss:0.12334
# [782]	validation_0-rmse:0.17534	validation_0-myloss:0.12333
# [783]	validation_0-rmse:0.17532	validation_0-myloss:0.12332
# [784]	validation_0-rmse:0.17529	validation_0-myloss:0.12330
# [785]	validation_0-rmse:0.17526	validation_0-myloss:0.12330
# [786]	validation_0-rmse:0.17524	validation_0-myloss:0.12328
# [787]	validation_0-rmse:0.17521	validation_0-myloss:0.12327
# [788]	validation_0-rmse:0.17520	validation_0-myloss:0.12327
# [789]	validation_0-rmse:0.17517	validation_0-myloss:0.12326
# [790]	validation_0-rmse:0.17513	validation_0-myloss:0.12323
# [791]	validation_0-rmse:0.17511	validation_0-myloss:0.12322
# [792]	validation_0-rmse:0.17508	validation_0-myloss:0.12321
# [793]	validation_0-rmse:0.17507	validation_0-myloss:0.12320
# [794]	validation_0-rmse:0.17504	validation_0-myloss:0.12318
	validation_0-rmse:0.16329	validation_0-myloss:0.11321
# [3759]	validation_0-rmse:0.16328	validation_0-myloss:0.11321
# [3760]	validation_0-rmse:0.16328	validation_0-myloss:0.11320
# [3761]	validation_0-rmse:0.16328	validation_0-myloss:0.11321
# [3762]	validation_0-rmse:0.16329	validation_0-myloss:0.11321
# [3763]	validation_0-rmse:0.16329	validation_0-myloss:0.11321
# [3764]	validation_0-rmse:0.16328	validation_0-myloss:0.11320
# [3765]	validation_0-rmse:0.16329	validation_0-myloss:0.11320
# [3766]	validation_0-rmse:0.16329	validation_0-myloss:0.11320
# [3767]	validation_0-rmse:0.16329	validation_0-myloss:0.11320
# [3768]	validation_0-rmse:0.16328	validation_0-myloss:0.11320
# [3769]	validation_0-rmse:0.16328	validation_0-myloss:0.11320
# [3770]	validation_0-rmse:0.16329	validation_0-myloss:0.11320
# [3771]	validation_0-rmse:0.16329	validation_0-myloss:0.11320
# [3772]	validation_0-rmse:0.16329	validation_0-myloss:0.11320
# [3773]	validation_0-rmse:0.16329	validation_0-myloss:0.11320
# [3774]	validation_0-rmse:0.16328	validation_0-myloss:0.11320
# [3775]	validation_0-rmse:0.16329	validation_0-myloss:0.11320
# [3776]	validation_0-rmse:0.16328	validation_0-myloss:0.11320
# [3777]	validation_0-rmse:0.16328	validation_0-myloss:0.11319
# [3778]	validation_0-rmse:0.16329	validation_0-myloss:0.11319
# [3779]	validation_0-rmse:0.16329	validation_0-myloss:0.11319
# [3780]	validation_0-rmse:0.16329	validation_0-myloss:0.11319
# [3781]	validation_0-rmse:0.16329	validation_0-myloss:0.11319
# [3782]	validation_0-rmse:0.16328	validation_0-myloss:0.11319
# [3783]	validation_0-rmse:0.16328	validation_0-myloss:0.11319
# [3784]	validation_0-rmse:0.16328	validation_0-myloss:0.11319
# [3785]	validation_0-rmse:0.16328	validation_0-myloss:0.11319
# [3786]	validation_0-rmse:0.16328	validation_0-myloss:0.11319
# [3787]	validation_0-rmse:0.16328	validation_0-myloss:0.11319
# [3788]	validation_0-rmse:0.16328	validation_0-myloss:0.11319
# [3789]	validation_0-rmse:0.16328	validation_0-myloss:0.11318
# [3790]	validation_0-rmse:0.16328	validation_0-myloss:0.11318
# [3791]	validation_0-rmse:0.16328	validation_0-myloss:0.11318
# [3792]	validation_0-rmse:0.16328	validation_0-myloss:0.11318
# [3793]	validation_0-rmse:0.16328	validation_0-myloss:0.11318
# [3794]	validation_0-rmse:0.16328	validation_0-myloss:0.11318
# [3795]	validation_0-rmse:0.16328	validation_0-myloss:0.11318
# [3796]	validation_0-rmse:0.16328	validation_0-myloss:0.11318
# [3797]	validation_0-rmse:0.16328	validation_0-myloss:0.11318
# [3798]	validation_0-rmse:0.16328	validation_0-myloss:0.11318
# [3799]	validation_0-rmse:0.16328	validation_0-myloss:0.11318
# [3800]	validation_0-rmse:0.16328	validation_0-myloss:0.11318
# [3801]	validation_0-rmse:0.16329	validation_0-myloss:0.11318
# [3802]	validation_0-rmse:0.16329	validation_0-myloss:0.11318
# [3803]	validation_0-rmse:0.16329	validation_0-myloss:0.11318
# [3804]	validation_0-rmse:0.16329	validation_0-myloss:0.11319
# [3805]	validation_0-rmse:0.16329	validation_0-myloss:0.11319
# [3806]	validation_0-rmse:0.16328	validation_0-myloss:0.11318
# [3807]	validation_0-rmse:0.16329	validation_0-myloss:0.11318
# [3808]	validation_0-rmse:0.16329	validation_0-myloss:0.11319
# [3809]	validation_0-rmse:0.16329	validation_0-myloss:0.11319
# [3810]	validation_0-rmse:0.16329	validation_0-myloss:0.11319
# [3811]	validation_0-rmse:0.16329	validation_0-myloss:0.11319
# [3812]	validation_0-rmse:0.16329	validation_0-myloss:0.11320
# [3813]	validation_0-rmse:0.16329	validation_0-myloss:0.11319
# [3814]	validation_0-rmse:0.16330	validation_0-myloss:0.11320
# [3815]	validation_0-rmse:0.16330	validation_0-myloss:0.11320
# [3816]	validation_0-rmse:0.16330	validation_0-myloss:0.11320
# [3817]	validation_0-rmse:0.16330	validation_0-myloss:0.11320
# [3818]	validation_0-rmse:0.16330	validation_0-myloss:0.11320
# [3819]	validation_0-rmse:0.16330	validation_0-myloss:0.11320
# [3820]	validation_0-rmse:0.16330	validation_0-myloss:0.11320
# [3821]	validation_0-rmse:0.16330	validation_0-myloss:0.11320
# [3822]	validation_0-rmse:0.16331	validation_0-myloss:0.11320
# [3823]	validation_0-rmse:0.16331	validation_0-myloss:0.11320
# [3824]	validation_0-rmse:0.16331	validation_0-myloss:0.11320
# [3825]	validation_0-rmse:0.16331	validation_0-myloss:0.11320
# [3826]	validation_0-rmse:0.16331	validation_0-myloss:0.11320
# [3827]	validation_0-rmse:0.16331	validation_0-myloss:0.11320
# [3828]	validation_0-rmse:0.16331	validation_0-myloss:0.11320
# [3829]	validation_0-rmse:0.16331	validation_0-myloss:0.11320
# [3830]	validation_0-rmse:0.16331	validation_0-myloss:0.11320
# [3831]	validation_0-rmse:0.16331	validation_0-myloss:0.11320
# [3832]	validation_0-rmse:0.16331	validation_0-myloss:0.11320
# [3833]	validation_0-rmse:0.16331	validation_0-myloss:0.11320
# [3834]	validation_0-rmse:0.16331	validation_0-myloss:0.11319
# [3835]	validation_0-rmse:0.16331	validation_0-myloss:0.11319
# [3836]	validation_0-rmse:0.16331	validation_0-myloss:0.11320
# [3837]	validation_0-rmse:0.16331	validation_0-myloss:0.11320
# [3838]	validation_0-rmse:0.16331	validation_0-myloss:0.11320
# [3839]	validation_0-rmse:0.16331	validation_0-myloss:0.11319
# [3840]	validation_0-rmse:0.16331	validation_0-myloss:0.11319
# [3841]	validation_0-rmse:0.16331	validation_0-myloss:0.11319
# [3842]	validation_0-rmse:0.16331	validation_0-myloss:0.11319
# [3843]	validation_0-rmse:0.16331	validation_0-myloss:0.11319
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.6,
#              early_stopping_rounds=50, enable_categorical=False,
#              eval_metric=<function myloss at 0x0000027C27D09990>,
#              feature_types=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.01, max_bin=256, max_cat_threshold=64,
#              max_cat_to_onehot=4, max_delta_step=0, max_depth=6, max_leaves=0,
#              min_child_weight=4, missing=nan, monotone_constraints='()',
#              n_estimators=30000, n_jobs=0, num_parallel_tree=1,
#              predictor='auto', random_state=42, ...)

# %%
importance_Score = bestXGB.get_booster().get_score(importance_type="gain")
sorted_idx = np.argsort(bestXGB.feature_importances_)[::-1]

# %%
pipe_final = Pipeline([
    ('preprocessor', mypreprocessor),
    ('model', XGBRegressor(colsample_bytree=0.6,
                           gamma = 0,
                           learning_rate=0.01,
                           reg_lambda = 0.01,
                           reg_alpha = 1,
                           max_depth=6,
                           min_child_weight=2,
                           n_estimators=3000,                                                                    
                           eval_metric = myloss,
                           subsample=0.9, seed = 42))
])

target_log = np.log(target)
pipe_final.fit(dat_train_after, target_log)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('KNNimputer',
#                                                                    KNNimputer_dat()),
#                                                                   ('scaler',
#                                                                    ColumnTransformer(transformers=[('std_scale',
#                                                                                                     StandardScaler(),
#                                                                                                     ['FinishedSquareFeet',
#                                                                                                      'GarageSquareFeet',
#                                                                                                      'LotSizeSquareFeet',
#                                                                                                      'BGMedHomeValue',
#                                                                                                      'BGMedRent',
#                                                                                                      'BGMedYearBuilt',
#                                                                                                      'BGMedIncome',
#                                                                                                      'BGMedAge',
#                                                                                                      'BuiltYear']),
#                                                                                                    ('Identity',
#                                                                                                     I...
#                               feature_types=None, gamma=0, gpu_id=-1,
#                               grow_policy='depthwise', importance_type=None,
#                               interaction_constraints='', learning_rate=0.01,
#                               max_bin=256, max_cat_threshold=64,
#                               max_cat_to_onehot=4, max_delta_step=0,
#                               max_depth=6, max_leaves=0, min_child_weight=2,
#                               missing=nan, monotone_constraints='()',
#                               n_estimators=3000, n_jobs=0, num_parallel_tree=1,
#                               predictor='auto', random_state=42, ...))])

# %%
#joblib.dump(pipe_final, 'XGBooster.pkl')
XGBooster = joblib.load('XGBooster.pkl')

# %%
y_pred = pipe_final.predict(dat_test_after)
output = {'PropertyID':dat_test['PropertyID'], 'SaleDollarCnt': np.exp(y_pred).round(3)}
output_dat = pd.DataFrame(output)
#output_dat.to_csv('Prediction_XGB.csv')

# %%
output_dat
# Out:
#       PropertyID  SaleDollarCnt
# 0       48735321   2.375323e+06
# 1       48735471   1.025143e+06
# 2       49128764   5.301614e+05
# 3       48897535   4.060026e+05
# 4       49083957   1.080858e+06
# ...          ...            ...
# 4397    49034257   2.749728e+05
# 4398    49101515   5.930839e+04
# 4399    49092758   1.778608e+05
# 4400    49034232   3.390675e+05
# 4401    49092730   1.882702e+05
#
# [4402 rows x 2 columns]

# %%
dat_test
# Out:
#       PropertyID   TransDate  censusblockgroup ZoneCodeCounty  Usecode  \
# 0       48735321  10/31/2015      530330001001        SF 9600        9
# 1       48735471   11/6/2015      530330001001        SF 9600        9
# 2       49128764  10/17/2015      530330001001        SF 7200        9
# 3       48897535  11/19/2015      530330001001        SF 7200        9
# 4       49083957  12/15/2015      530330001001        SF 9600        9
# ...          ...         ...               ...            ...      ...
# 4397    49034257  12/16/2015      530330328003          RA2.5        9
# 4398    49101515   12/8/2015      530330328003              F        9
# 4399    49092758   10/6/2015      530330328003          RA2.5        9
# 4400    49034232  11/21/2015      530330328003          RA2.5        9
# 4401    49092730  10/31/2015      530330328003          RA2.5        9
#
#       BedroomCnt  BathroomCnt  FinishedSquareFeet  GarageSquareFeet  \
# 0            5.0     4.000000                5540               NaN
# 1            5.0     3.000000                2470             510.0
# 2            4.0     2.000000                1680               NaN
# 3            2.0     1.000000                 990             260.0
# 4            4.0     3.000000                2960             550.0
# ...          ...          ...                 ...               ...
# 4397         3.0     2.000000                1420               NaN
# 4398         2.0     2.560000                 730               NaN
# 4399         2.0     1.000000                 770               NaN
# 4400         3.0     1.942308                2250               NaN
# 4401         2.0     1.000000                 960               NaN
#
#       LotSizeSquareFeet  ...  Latitude  Longitude  BGMedHomeValue  BGMedRent  \
# 0                 25338  ...  47725642 -122283771        527700.0     1750.0
# 1                 26006  ...  47726993 -122281969        527700.0     1750.0
# 2                  8743  ...  47731749 -122289304        527700.0     1750.0
# 3                 12219  ...  47728810 -122289224        527700.0     1750.0
# 4                 23568  ...  47731170 -122282684        527700.0     1750.0
# ...                 ...  ...       ...        ...             ...        ...
# 4397              13590  ...  47758782 -121472451        180600.0      507.0
# 4398              11758  ...  47713245 -121171762        180600.0      507.0
# 4399              15141  ...  47713748 -121322193        180600.0      507.0
# 4400              15600  ...  47760904 -121475524        180600.0      507.0
# 4401              10374  ...  47712544 -121313944        180600.0      507.0
#
#       BGMedYearBuilt  BGPctOwn  BGPctVacant  BGMedIncome  BGPctKids  BGMedAge
# 0             1956.0    0.9134       0.1061       113450     0.2524      49.6
# 1             1956.0    0.9134       0.1061       113450     0.2524      49.6
# 2             1956.0    0.9134       0.1061       113450     0.2524      49.6
# 3             1956.0    0.9134       0.1061       113450     0.2524      49.6
# 4             1956.0    0.9134       0.1061       113450     0.2524      49.6
# ...              ...       ...          ...          ...        ...       ...
# 4397          1971.0    0.6477       0.6384        26979     0.1317      48.5
# 4398          1971.0    0.6477       0.6384        26979     0.1317      48.5
# 4399          1971.0    0.6477       0.6384        26979     0.1317      48.5
# 4400          1971.0    0.6477       0.6384        26979     0.1317      48.5
# 4401          1971.0    0.6477       0.6384        26979     0.1317      48.5
#
# [4402 rows x 23 columns]

# %% [markdown]
# ## GradientBoostring

# %%
pipe2 = Pipeline([
    ('preprocessor', mypreprocessor),
    ('model', GradientBoostingRegressor(learning_rate = 1e-3,
                                        n_estimators = 200,
                                        max_depth = 5,
                                        max_features = None,
                                        min_samples_leaf = 3,
                                        loss = 'squared_error'))
])

param_grid2 = {'model__learning_rate': [0.1],
               'model_subsample:' [0.3, 0.6, 0.8, 1]
               'model__max_depth':[5, 7, 10],
               'model__n_estimators': [300],
               'model__max_features': [0.5, 0.6, 0.8, 1],
               'model__min_samples_leaf':[1, 3, 5]
             }

# %%
grid_search = GridSearchCV(pipe2, param_grid2, scoring=myscore, n_jobs=-1)
target_log = np.log(y_train)
grid_search.fit(X_train, target_log)
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('KNNimputer',
#                                                                                           KNNImputer(n_neighbors=10)),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['BedroomCnt',
#                                                                           'BathroomCnt',
#                                                                           'StoryCnt',
#                                                                           'FinishedSquareFeet',
#                                                                           'GarageSquareFeet',
#                                                                           'LotSizeSquareFeet',
#                                                                           'BGMedHomeValue',
#                                                                           'BGMedRent',
#                                                                           'BGMedYearBuilt',
#                                                                           'BGPctOwn',
#                                                                           'BGPctVacant...
#                                                                          OneHotEncoder(),
#                                                                          ['ViewType'])])),
#                                        ('model',
#                                         GradientBoostingRegressor(learning_rate=0.001,
#                                                                   max_depth=5,
#                                                                   min_samples_leaf=3,
#                                                                   n_estimators=200))]),
#              n_jobs=-1,
#              param_grid={'model__learning_rate': [0.1], 'model__max_depth': [7],
#                          'model__max_features': [None],
#                          'model__min_samples_leaf': [5],
#                          'model__n_estimators': [300]},
#              scoring=make_scorer(myloss, greater_is_better=False))

# %%
#joblib.dump(grid_search, 'GradientBoosting2.pkl')
#gs = joblib.load('GradientBoosting2.pkl')

# %%
best_GBoosting = Pipeline([
    ('preprocessor', mypreprocessor),
    ('model', GradientBoostingRegressor(learning_rate = 0.01,
                                        subsample=0.8,
                                        n_estimators = 3000,
                                        max_depth = 7,
                                        max_features = 0.8,
                                        min_samples_leaf = 5,
                                        loss = 'squared_error'))
])

best_GBoosting.fit(dat_train_after, np.log(target))
#y_pred = best_GBoosting.predict(X_test)
#mean_absolute_percentage_error(y_test, np.exp(y_pred))

# %%
y_pred = best_GBoosting.predict(dat_test_after)

# %%
output = {'PropertyID':dat_test['PropertyID'], 'SaleDollarCnt': np.exp(y_pred).round(3)}
output_dat.to_csv('Prediction1_GB.csv')

# %% [markdown]
# ## ensembled by Superlearn

# %%
superlearner = SuperLearner()

XGB = XGBRegressor(colsample_bytree=0.6,
                           gamma = 0,
                           learning_rate=0.01,
                           reg_lambda = 0.01,
                           reg_alpha = 1,
                           max_depth=6,
                           min_child_weight=2,
                           n_estimators=3000,                                                                    
                           eval_metric = myloss,
                           subsample=0.9, seed = 42)

GradB = GradientBoostingRegressor(learning_rate = 0.01,
                                  subsample=0.8,
                                  n_estimators = 3000,
                                  max_depth = 7,
                                  max_features = 0.8,
                                  min_samples_leaf = 5,
                                  loss = 'squared_error')

RandomForest = RandomForestRegressor(max_samples=0.8,
                                    n_estimators = 2000,
                                    max_depth = 7,
                                    min_samples_split = 2,
                                    max_features = 0.8,
                                    min_samples_leaf = 5)

superlearner.add([('XGB', XGB), 
                  ('GradientBooster', GradB),
                  ('Random Forest', RandomForest)], preprocessing=[mypreprocessor])
superlearner.add_meta(XGB)
superlearner.fit(X_train, np.log(y_train))
# Out:
# SuperLearner(array_check=None, backend=None, folds=2,
#        layers=[Layer(backend='threading', dtype=<class 'numpy.float32'>, n_jobs=-1,
#    name='layer-1', propagate_features=None, raise_on_exception=True,
#    random_state=None, shuffle=False,
#    stack=[Group(backend='threading', dtype=<class 'numpy.float32'>,
#    indexer=FoldIndex(X=None, folds=2, raise_on_ex...rer=None)],
#    n_jobs=-1, name='group-7', raise_on_exception=True, transformers=[])],
#    verbose=0)],
#        model_selection=False, n_jobs=None, raise_on_exception=True,
#        random_state=None, sample_size=20, scorer=None, shuffle=False,
#        verbose=False)

# %%
y_pred = superlearner.predict(X_test)
mean_absolute_percentage_error(y_test, np.exp(y_pred))
# Out:
# 0.13811785259455533

# %%
pipe_final = Pipeline([
    ('preprocessor', mypreprocessor),
    ('model', XGBRegressor(colsample_bytree=0.6,
                           gamma = 0,
                           learning_rate=0.01,
                           reg_lambda = 0.01,
                           reg_alpha = 1,
                           max_depth=6,
                           min_child_weight=2,
                           n_estimators=3000,                                                                    
                           subsample=0.9, seed = 42))
])

pipe_final.fit(X_train, np.log(y_train))
y_pred = pipe_final.predict(X_test)
mean_absolute_percentage_error(y_test, np.exp(y_pred))
# Out:
# 0.13138988603300247

# %%
pipe = Pipeline([
    ('preprocessor', mypreprocessor),
    ('model', RandomForestRegressor(max_samples=0.9,
                                    n_estimators = 2000,
                                    max_depth = 10,
                                    min_samples_split = 2,
                                    max_features = 0.6,
                                    min_samples_leaf = 5))
])

pipe.fit(X_train, np.log(y_train))
y_pred = pipe.predict(X_test)
mean_absolute_percentage_error(y_test, np.exp(y_pred))
# Out:
# 0.14822342410187062

# %%
company=["A","B","C"]

data=pd.DataFrame({
    "company":[company[x] for x in np.random.randint(0,len(company),10)],
    "salary":np.random.randint(5,50,10),
    "age":np.random.randint(15,50,10)
}
)

# %%
data
# Out:
#   company  salary  age
# 0       C      13   46
# 1       B      30   48
# 2       C      31   44
# 3       C      16   15
# 4       B      23   46
# 5       A      42   28
# 6       B      15   43
# 7       A      22   28
# 8       A      48   23
# 9       A      24   16

# %%
avg_salary_dict = data.groupby('company')['salary'].mean().to_dict()
data['avg_salary'] = data['company'].map(avg_salary_dict)

# %%
def get_ordest(x):
    df = x.sort_values(by = 'age', ascending=False)
    return df['age'].iloc[0]

data.groupby('company').apply(get_ordest)
# Out:
# company
# A    47
# B    45
# C    47
# dtype: int32
